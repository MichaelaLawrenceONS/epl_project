# %%
import pandas as pd
# Out:
# C:\Users\lawrem1\Anaconda3\lib\site-packages\setuptools\distutils_patch.py:25: UserWarning: Distutils was imported before Setuptools. This usage is discouraged and may exhibit undesirable behaviors or errors. Please use Setuptools' objects directly or at least import Setuptools first.
#   warnings.warn(

# %%
df = pd.read_csv('olympics2000.csv')

# %%
df.describe(include = 'all')
# Out:
#                      edition     edition_id country_noc_x      sport  \
# count                 112404  112404.000000        112404     112404
# unique                    12            NaN           212         65
# top     2020 Summer Olympics            NaN           USA  Athletics
# freq                   14816            NaN          6705      14300
# mean                     NaN      48.869417           NaN        NaN
# std                      NaN      13.893157           NaN        NaN
# min                      NaN      25.000000           NaN        NaN
# 25%                      NaN      47.000000           NaN        NaN
# 50%                      NaN      54.000000           NaN        NaN
# 75%                      NaN      59.000000           NaN        NaN
# max                      NaN      62.000000           NaN        NaN
#
#                 event     result_id         athlete    athlete_id     pos  \
# ...

# %%
df.dtypes
# Out:
# edition           object
# edition_id         int64
# country_noc_x     object
# sport             object
# event             object
# result_id          int64
# athlete           object
# athlete_id         int64
# pos               object
# medal             object
# isTeamSport         bool
# name              object
# sex               object
# born              object
# height           float64
# weight            object
# country           object
# country_noc_y     object
# description       object
# special_notes     object
# dtype: object

# %%
5555/16222
# Out:
# 0.34243619775613365

# %%
df['medal'].value_counts()
# Out:
# Bronze    5555
# Gold      5357
# Silver    5310
# Name: medal, dtype: int64

# %%
df['pos'].value_counts()
# Out:
# 1             5361
# 2             5305
# 3             4989
# 4             4970
# 5             4647
#               ...
# 3 h9 r1/4        1
# 3 h8 r2/4        1
# 5 h11 r1/4       1
# 8 h10 r1/3       1
# 2 r1/2           1
# Name: pos, Length: 929, dtype: int64

# %%
df_football = df[df['event']=='Football, Men']
df_football[df_football['medal']=='Gold'].head()
#df_football.head()
# Out:
#                    edition  edition_id country_noc_x     sport          event  \
# 2211  2000 Summer Olympics          25           CMR  Football  Football, Men
# 2212  2000 Summer Olympics          25           CMR  Football  Football, Men
# 2213  2000 Summer Olympics          25           CMR  Football  Football, Men
# 2214  2000 Summer Olympics          25           CMR  Football  Football, Men
# 2215  2000 Summer Olympics          25           CMR  Football  Football, Men
#
#       result_id            athlete  athlete_id pos medal  isTeamSport  \
# 2211      34161     Aaron Nguimbat       91019   1  Gold         True
# 2212      34161   Albert Meyong Zé       91016   1  Gold         True
# 2213      34161      Clément Beaud       91007   1  Gold         True
# 2214      34161      Daniel Bekono       91008   1  Gold         True
# 2215      34161  Daniel N'Gom Komé       91018   1  Gold         True
#
#                    name   sex             born  height weight    country  \
# ...

# %%
df_weird = df[df['medal']=='Gold']
df_weird = df_weird[df_weird['pos']!='1']
df_weird = df_weird[df_weird['pos']!='=1']
df_weird
# Out:
# Empty DataFrame
# Columns: [edition, edition_id, country_noc_x, sport, event, result_id, athlete, athlete_id, pos, medal, isTeamSport, name, sex, born, height, weight, country, country_noc_y, description, special_notes]
# Index: []
